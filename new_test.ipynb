# %%
print('avijti')
# Out:
# avijti

# %%
print('My name is Avijit Biswas')
# Out:
# My name is Avijit Biswas

# %%
print('avijt')
# Out:
# avijt

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
cars_data = pd.read_csv('D:\Pyn\online learning\data_science_class\February_01 MLR Assumptions Test Script\Cars.csv')

# %%
cars_data.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
cars_data.shape
# Out:
# (81, 5)

# %%
cars_data.isnull().sum()
# Out:
# HP     0
# MPG    0
# VOL    0
# SP     0
# WT     0
# dtype: int64

# %%
cars_data.dtypes
# Out:
# HP       int64
# MPG    float64
# VOL      int64
# SP     float64
# WT     float64
# dtype: object

# %%
sns.distplot(a=cars_data['HP'],hist=False)
# plt.title('HP Distribution')
# plt.show()
# Out:
# <Axes: xlabel='HP', ylabel='Density'>

# %%
cars_data.columns
# Out:
# Index(['HP', 'MPG', 'VOL', 'SP', 'WT'], dtype='object')

# %%
cars_data.head(2)
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833

# %%
sns.distplot(cars_data['HP'],hist=False)
# Out:
# <Axes: xlabel='HP', ylabel='Density'>

# %%
sns.distplot(a=cars_data['SP'], rug=False,norm_hist=True)
# Out:
# <Axes: xlabel='SP', ylabel='Density'>

# %%
sns.distplot(a=cars_data('VOL'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 sns.distplot(a=cars_data('VOL'))
#
# TypeError: 'DataFrame' object is not callable
